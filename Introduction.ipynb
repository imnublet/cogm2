# %%
import ccm
from ccm.lib.actr import *
import numpy as np

# %%
log=ccm.log()

class Hanoi_env(ACTR):
    A = Buffer()
    B = Buffer()
    C = Buffer()
    hand = Buffer()
    steps = Buffer()


    def init():
        A.set('top:3 mid:2 bot:1')
        B.set('top:None mid:None bot:None')
        C.set('top:None mid:None bot:None')
        hand.set('disc:None')
        steps.set('step:0')

    def hanoi_finished(C='top:3 mid:2 bot:1'):
        A.clear()
        B.clear()
        C.clear()
        hand.clear()
        total_steps = steps.__getitem__('step')
        f = open("results.txt", "a")
        f.write(total_steps+'\n')
        f.close()
        print 'finished'
        print 'this took', total_steps, 'steps to complete'


    def pick_from_A(hand='disc:None'):
        if A.__getitem__('top') != 'None':
            hand.modify(disc=str(A.__getitem__('top')))
            A.modify(top='None')
        elif A.__getitem__('mid') != 'None':
            hand.modify(disc=A.__getitem__('mid'))
            A.modify(mid='None')
        elif A.__getitem__('bot') != 'None':
            hand.modify(disc=A.__getitem__('bot'))
            A.modify(bot='None')


    def pick_from_B(hand='disc:None'):
        if B.__getitem__('top') != 'None':
            hand.modify(disc=str(B.__getitem__('top')))
            B.modify(top='None')
        elif B.__getitem__('mid') != 'None':
            hand.modify(disc=B.__getitem__('mid'))
            B.modify(mid='None')
        elif B.__getitem__('bot') != 'None':
            hand.modify(disc=B.__getitem__('bot'))
            B.modify(bot='None')

    def pick_from_C(hand='disc:None'):
        if C.__getitem__('top') != 'None':
            hand.modify(disc=str(C.__getitem__('top')))
            C.modify(top='None')
        elif C.__getitem__('mid') != 'None':
            hand.modify(disc=C.__getitem__('mid'))
            C.modify(mid='None')
        elif C.__getitem__('bot') != 'None':
            hand.modify(disc=C.__getitem__('bot'))
            C.modify(bot='None')



    def move_to_A(hand='disc:?d', A='top:?x mid:?y bot:?z'):
        if hand.__getitem__('disc') != 'None':
            if str(z) == 'None':
                A.modify(bot=str(d))
                hand.modify(disc='None')
            elif str(y) == 'None' and str(z)!= 'None' and int(d) > int(z):
                A.modify(mid=str(d))
                hand.modify(disc='None')
            elif str(x) == 'None' and str(y)!= 'None' and int(d) > int(y):
                A.modify(top=str(d))
                hand.modify(disc='None')


    def move_to_B(hand='disc:?d', B='top:?x mid:?y bot:?z'):
        if hand.__getitem__('disc') != 'None':
            if str(z) == 'None':
                B.modify(bot=str(d))
                hand.modify(disc='None')
            elif str(y) == 'None' and str(z)!= 'None' and int(d) > int(z):
                B.modify(mid=str(d))
                hand.modify(disc='None')
            elif str(x) == 'None' and str(y)!= 'None' and int(d) > int(y):
                B.modify(top=str(d))
                hand.modify(disc='None')

    def move_to_C(hand='disc:?d', C='top:?x mid:?y bot:?z'):
        if hand.__getitem__('disc') != 'None':
            if str(z) == 'None':
                C.modify(bot=str(d))
                hand.modify(disc='None')
            elif str(y) == 'None' and str(z)!= 'None' and int(d) > int(z):
                C.modify(mid=str(d))
                hand.modify(disc='None')
            elif str(x) == 'None' and str(y)!= 'None' and int(d) > int(y):
                C.modify(top=str(d))
                hand.modify(disc='None')

# %%
#Run model
model=Hanoi_env()

ccm.log_everything(model)
model.A.set('top:3 mid:2 bot:1')
model.run()
# Out:
#   91.600 production_threshold None
#   91.600 production_time_sd None
#   91.600 production_match_delay 0
#   91.600 production_time 0.05
#   91.600 A.chunk bot:1 mid:2 top:3
#    0.050 production None
#    0.050 production pick_from_B
#    0.100 production None
#    0.100 production pick_from_A
#    0.150 production None
#    0.150 hand.chunk disc:3
#    0.150 A.chunk bot:1 mid:2 top:None
#    0.150 production move_to_A
#    0.200 production None
#    0.200 A.chunk bot:1 mid:2 top:3
#    0.200 hand.chunk disc:None
#    0.200 production move_to_A
#    0.250 production None
#    0.250 production pick_from_A
#    0.300 production None
#    0.300 hand.chunk disc:3
#    0.300 A.chunk bot:1 mid:2 top:None
#    0.300 production move_to_C
#    0.350 production None
#    0.350 C.chunk bot:3 mid:None top:None
#    0.350 hand.chunk disc:None
#    0.350 production pick_from_A
#    0.400 production None
#    0.400 hand.chunk disc:2
#    0.400 A.chunk bot:1 mid:None top:None
#    0.400 production move_to_B
#    0.450 production None
#    0.450 B.chunk bot:2 mid:None top:None
#    0.450 hand.chunk disc:None
#    0.450 production pick_from_C
#    0.500 production None
#    0.500 hand.chunk disc:3
#    0.500 C.chunk bot:None mid:None top:None
#    0.500 production move_to_B
#    0.550 production None
#    0.550 B.chunk bot:2 mid:3 top:None
#    0.550 hand.chunk disc:None
#    0.550 production move_to_A
#    0.600 production None
#    0.600 production move_to_B
#    0.650 production None
#    0.650 production pick_from_A
#    0.700 production None
#    0.700 hand.chunk disc:1
#    0.700 A.chunk bot:None mid:None top:None
#    0.700 production move_to_B
#    0.750 production None
#    0.750 production move_to_B
#    0.800 production None
#    0.800 production move_to_A
#    0.850 production None
#    0.850 A.chunk bot:1 mid:None top:None
#    0.850 hand.chunk disc:None
#    0.850 production move_to_A
#    0.900 production None
#    0.900 production pick_from_C
#    0.950 production None
#    0.950 production pick_from_C
#    1.000 production None
#    1.000 production move_to_C
#    1.050 production None
#    1.050 production move_to_A
#    1.100 production None
#    1.100 production pick_from_A
#    1.150 production None
#    1.150 hand.chunk disc:1
#    1.150 A.chunk bot:None mid:None top:None
#    1.150 production move_to_C
#    1.200 production None
#    1.200 C.chunk bot:1 mid:None top:None
#    1.200 hand.chunk disc:None
#    1.200 production move_to_C
#    1.250 production None
#    1.250 production pick_from_A
#    1.300 production None
#    1.300 production move_to_B
#    1.350 production None
#    1.350 production pick_from_C
#    1.400 production None
#    1.400 hand.chunk disc:1
#    1.400 C.chunk bot:None mid:None top:None
#    1.400 production move_to_A
#    1.450 production None
#    1.450 A.chunk bot:1 mid:None top:None
#    1.450 hand.chunk disc:None
#    1.450 production pick_from_A
#    1.500 production None
#    1.500 hand.chunk disc:1
#    1.500 A.chunk bot:None mid:None top:None
#    1.500 production move_to_B
#    1.550 production None
#    1.550 production move_to_A
#    1.600 production None
#    1.600 A.chunk bot:1 mid:None top:None
#    1.600 hand.chunk disc:None
#    1.600 production pick_from_A
#    1.650 production None
#    1.650 hand.chunk disc:1
#    1.650 A.chunk bot:None mid:None top:None
#    1.650 production move_to_A
#    1.700 production None
#    1.700 A.chunk bot:1 mid:None top:None
#    1.700 hand.chunk disc:None
#    1.700 production pick_from_B
#    1.750 production None
#    1.750 hand.chunk disc:3
#    1.750 B.chunk bot:2 mid:None top:None
#    1.750 production move_to_B
#    1.800 production None
#    1.800 B.chunk bot:2 mid:3 top:None
#    1.800 hand.chunk disc:None
#    1.800 production move_to_A
#    1.850 production None
#    1.850 production move_to_C
#    1.900 production None
#    1.900 production pick_from_B
#    1.950 production None
#    1.950 hand.chunk disc:3
#    1.950 B.chunk bot:2 mid:None top:None
#    1.950 production move_to_A
#    2.000 production None
#    2.000 A.chunk bot:1 mid:3 top:None
#    2.000 hand.chunk disc:None
#    2.000 production pick_from_B
#    2.050 production None
#    2.050 hand.chunk disc:2
#    2.050 B.chunk bot:None mid:None top:None
#    2.050 production move_to_C
#    2.100 production None
#    2.100 C.chunk bot:2 mid:None top:None
#    2.100 hand.chunk disc:None
#    2.100 production move_to_C
#    2.150 production None
#    2.150 production pick_from_A
#    2.200 production None
#    2.200 hand.chunk disc:3
#    2.200 A.chunk bot:1 mid:None top:None
#    2.200 production move_to_C
#    2.250 production None
#    2.250 C.chunk bot:2 mid:3 top:None
#    2.250 hand.chunk disc:None
#    2.250 production move_to_A
#    2.300 production None
#    2.300 production move_to_C
#    2.350 production None
#    2.350 production move_to_B
#    2.400 production None
#    2.400 production move_to_B
#    2.450 production None
#    2.450 production pick_from_C
#    2.500 production None
#    2.500 hand.chunk disc:3
#    2.500 C.chunk bot:2 mid:None top:None
#    2.500 production move_to_B
#    2.550 production None
#    2.550 B.chunk bot:3 mid:None top:None
#    2.550 hand.chunk disc:None
#    2.550 production pick_from_A
#    2.600 production None
#    2.600 hand.chunk disc:1
#    2.600 A.chunk bot:None mid:None top:None
#    2.600 production move_to_C
#    2.650 production None
#    2.650 production move_to_A
#    2.700 production None
#    2.700 A.chunk bot:1 mid:None top:None
#    2.700 hand.chunk disc:None
#    2.700 production move_to_C
#    2.750 production None
#    2.750 production move_to_B
#    2.800 production None
#    2.800 production pick_from_C
#    2.850 production None
#    2.850 hand.chunk disc:2
#    2.850 C.chunk bot:None mid:None top:None
#    2.850 production move_to_B
#    2.900 production None
#    2.900 production move_to_C
#    2.950 production None
#    2.950 C.chunk bot:2 mid:None top:None
#    2.950 hand.chunk disc:None
#    2.950 production pick_from_B
#    3.000 production None
#    3.000 hand.chunk disc:3
#    3.000 B.chunk bot:None mid:None top:None
#    3.000 production move_to_C
#    3.050 production None
#    3.050 C.chunk bot:2 mid:3 top:None
#    3.050 hand.chunk disc:None
#    3.050 production pick_from_A
#    3.100 production None
#    3.100 hand.chunk disc:1
#    3.100 A.chunk bot:None mid:None top:None
#    3.100 production move_to_A
#    3.150 production None
#    3.150 A.chunk bot:1 mid:None top:None
#    3.150 hand.chunk disc:None
#    3.150 production pick_from_C
#    3.200 production None
#    3.200 hand.chunk disc:3
#    3.200 C.chunk bot:2 mid:None top:None
#    3.200 production move_to_C
#    3.250 production None
#    3.250 C.chunk bot:2 mid:3 top:None
#    3.250 hand.chunk disc:None
#    3.250 production move_to_A
#    3.300 production None
#    3.300 production pick_from_A
#    3.350 production None
#    3.350 hand.chunk disc:1
#    3.350 A.chunk bot:None mid:None top:None
#    3.350 production move_to_A
#    3.400 production None
#    3.400 A.chunk bot:1 mid:None top:None
#    3.400 hand.chunk disc:None
#    3.400 production pick_from_A
#    3.450 production None
#    3.450 hand.chunk disc:1
#    3.450 A.chunk bot:None mid:None top:None
#    3.450 production move_to_C
#    3.500 production None
#    3.500 production move_to_C
#    3.550 production None
#    3.550 production move_to_B
#    3.600 production None
#    3.600 B.chunk bot:1 mid:None top:None
#    3.600 hand.chunk disc:None
#    3.600 production move_to_C
#    3.650 production None
#    3.650 production move_to_B
#    3.700 production None
#    3.700 production pick_from_A
#    3.750 production None
#    3.750 production pick_from_B
#    3.800 production None
#    3.800 hand.chunk disc:1
#    3.800 B.chunk bot:None mid:None top:None
#    3.800 production move_to_A
#    3.850 production None
#    3.850 A.chunk bot:1 mid:None top:None
#    3.850 hand.chunk disc:None
#    3.850 production move_to_C
#    3.900 production None
#    3.900 production move_to_B
#    3.950 production None
#    3.950 production pick_from_C
#    4.000 production None
#    4.000 hand.chunk disc:3
#    4.000 C.chunk bot:2 mid:None top:None
#    4.000 production move_to_C
#    4.050 production None
#    4.050 C.chunk bot:2 mid:3 top:None
#    4.050 hand.chunk disc:None
#    4.050 production pick_from_B
#    4.100 production None
#    4.100 production move_to_C
#    4.150 production None
#    4.150 production move_to_A
#    4.200 production None
#    4.200 production pick_from_B
#    4.250 production None
#    4.250 production pick_from_A
#    4.300 production None
#    4.300 hand.chunk disc:1
#    4.300 A.chunk bot:None mid:None top:None
#    4.300 production move_to_A
#    4.350 production None
#    4.350 A.chunk bot:1 mid:None top:None
#    4.350 hand.chunk disc:None
#    4.350 production move_to_C
#    4.400 production None
#    4.400 production pick_from_B
#    4.450 production None
#    4.450 production pick_from_A
#    4.500 production None
#    4.500 hand.chunk disc:1
#    4.500 A.chunk bot:None mid:None top:None
#    4.500 production move_to_B
#    4.550 production None
#    4.550 B.chunk bot:1 mid:None top:None
#    4.550 hand.chunk disc:None
#    4.550 production pick_from_B
#    4.600 production None
#    4.600 hand.chunk disc:1
#    4.600 B.chunk bot:None mid:None top:None
#    4.600 production move_to_B
#    4.650 production None
#    4.650 B.chunk bot:1 mid:None top:None
#    4.650 hand.chunk disc:None
#    4.650 production move_to_B
#    4.700 production None
#    4.700 production move_to_C
#    4.750 production None
#    4.750 production pick_from_C
#    4.800 production None
#    4.800 hand.chunk disc:3
#    4.800 C.chunk bot:2 mid:None top:None
#    4.800 production move_to_A
#    4.850 production None
#    4.850 A.chunk bot:3 mid:None top:None
#    4.850 hand.chunk disc:None
#    4.850 production pick_from_A
#    4.900 production None
#    4.900 hand.chunk disc:3
#    4.900 A.chunk bot:None mid:None top:None
#    4.900 production move_to_C
#    4.950 production None
#    4.950 C.chunk bot:2 mid:3 top:None
#    4.950 hand.chunk disc:None
#    4.950 production move_to_B
#    5.000 production None
#    5.000 production move_to_A
#    5.050 production None
#    5.050 production move_to_C
#    5.100 production None
#    5.100 production pick_from_C
#    5.150 production None
#    5.150 hand.chunk disc:3
#    5.150 C.chunk bot:2 mid:None top:None
#    5.150 production move_to_B
#    5.200 production None
#    5.200 B.chunk bot:1 mid:3 top:None
#    5.200 hand.chunk disc:None
#    5.200 production pick_from_C
#    5.250 production None
#    5.250 hand.chunk disc:2
#    5.250 C.chunk bot:None mid:None top:None
#    5.250 production move_to_C
#    5.300 production None
#    5.300 C.chunk bot:2 mid:None top:None
#    5.300 hand.chunk disc:None
#    5.300 production move_to_A
#    5.350 production None
#    5.350 production move_to_C
#    5.400 production None
#    5.400 production move_to_A
#    5.450 production None
#    5.450 production move_to_C
#    5.500 production None
#    5.500 production move_to_C
#    5.550 production None
#    5.550 production pick_from_A
#    5.600 production None
#    5.600 production pick_from_C
#    5.650 production None
#    5.650 hand.chunk disc:2
#    5.650 C.chunk bot:None mid:None top:None
#    5.650 production move_to_B
#    5.700 production None
#    5.700 production move_to_A
#    5.750 production None
#    5.750 A.chunk bot:2 mid:None top:None
#    5.750 hand.chunk disc:None
#    5.750 production move_to_A
#    5.800 production None
#    5.800 production move_to_B
#    5.850 production None
#    5.850 production pick_from_C
#    5.900 production None
#    5.900 production move_to_C
#    5.950 production None
#    5.950 production pick_from_B
#    6.000 production None
#    6.000 hand.chunk disc:3
#    6.000 B.chunk bot:1 mid:None top:None
#    6.000 production move_to_A
#    6.050 production None
#    6.050 A.chunk bot:2 mid:3 top:None
#    6.050 hand.chunk disc:None
#    6.050 production pick_from_B
#    6.100 production None
#    6.100 hand.chunk disc:1
#    6.100 B.chunk bot:None mid:None top:None
#    6.100 production move_to_B
#    6.150 production None
#    6.150 B.chunk bot:1 mid:None top:None
#    6.150 hand.chunk disc:None
#    6.150 production move_to_B
#    6.200 production None
#    6.200 production pick_from_B
#    6.250 production None
#    6.250 hand.chunk disc:1
#    6.250 B.chunk bot:None mid:None top:None
#    6.250 production move_to_A
#    6.300 production None
#    6.300 production move_to_B
#    6.350 production None
#    6.350 B.chunk bot:1 mid:None top:None
#    6.350 hand.chunk disc:None
#    6.350 production pick_from_A
#    6.400 production None
#    6.400 hand.chunk disc:3
#    6.400 A.chunk bot:2 mid:None top:None
#    6.400 production move_to_A
#    6.450 production None
#    6.450 A.chunk bot:2 mid:3 top:None
#    6.450 hand.chunk disc:None
#    6.450 production move_to_C
#    6.500 production None
#    6.500 production move_to_C
#    6.550 production None
#    6.550 production move_to_B
#    6.600 production None
#    6.600 production pick_from_C
#    6.650 production None
#    6.650 production pick_from_B
#    6.700 production None
#    6.700 hand.chunk disc:1
#    6.700 B.chunk bot:None mid:None top:None
#    6.700 production move_to_A
#    6.750 production None
#    6.750 production move_to_C
#    6.800 production None
#    6.800 C.chunk bot:1 mid:None top:None
#    6.800 hand.chunk disc:None
#    6.800 production move_to_B
#    6.850 production None
#    6.850 production move_to_B
#    6.900 production None
#    6.900 production pick_from_C
#    6.950 production None
#    6.950 hand.chunk disc:1
#    6.950 C.chunk bot:None mid:None top:None
#    6.950 production move_to_A
#    7.000 production None
#    7.000 production move_to_A
#    7.050 production None
#    7.050 production move_to_C
#    7.100 production None
#    7.100 C.chunk bot:1 mid:None top:None
#    7.100 hand.chunk disc:None
#    7.100 production move_to_A
#    7.150 production None
#    7.150 production move_to_A
#    7.200 production None
#    7.200 production pick_from_C
#    7.250 production None
#    7.250 hand.chunk disc:1
#    7.250 C.chunk bot:None mid:None top:None
#    7.250 production move_to_C
#    7.300 production None
#    7.300 C.chunk bot:1 mid:None top:None
#    7.300 hand.chunk disc:None
#    7.300 production pick_from_C
#    7.350 production None
#    7.350 hand.chunk disc:1
#    7.350 C.chunk bot:None mid:None top:None
#    7.350 production move_to_C
#    7.400 production None
#    7.400 C.chunk bot:1 mid:None top:None
#    7.400 hand.chunk disc:None
#    7.400 production pick_from_C
#    7.450 production None
#    7.450 hand.chunk disc:1
#    7.450 C.chunk bot:None mid:None top:None
#    7.450 production move_to_A
#    7.500 production None
#    7.500 production move_to_A
#    7.550 production None
#    7.550 production move_to_B
#    7.600 production None
#    7.600 B.chunk bot:1 mid:None top:None
#    7.600 hand.chunk disc:None
#    7.600 production pick_from_C
#    7.650 production None
#    7.650 production move_to_B
#    7.700 production None
#    7.700 production move_to_B
#    7.750 production None
#    7.750 production move_to_A
#    7.800 production None
#    7.800 production pick_from_B
#    7.850 production None
#    7.850 hand.chunk disc:1
#    7.850 B.chunk bot:None mid:None top:None
#    7.850 production move_to_A
#    7.900 production None
#    7.900 production move_to_B
#    7.950 production None
#    7.950 B.chunk bot:1 mid:None top:None
#    7.950 hand.chunk disc:None
#    7.950 production move_to_A
#    8.000 production None
#    8.000 production pick_from_C
#    8.050 production None
#    8.050 production pick_from_A
#    8.100 production None
#    8.100 hand.chunk disc:3
#    8.100 A.chunk bot:2 mid:None top:None
#    8.100 production move_to_A
#    8.150 production None
#    8.150 A.chunk bot:2 mid:3 top:None
#    8.150 hand.chunk disc:None
#    8.150 production move_to_C
#    8.200 production None
#    8.200 production move_to_C
#    8.250 production None
#    8.250 production pick_from_C
#    8.300 production None
#    8.300 production pick_from_C
#    8.350 production None
#    8.350 production move_to_A
#    8.400 production None
#    8.400 production pick_from_B
#    8.450 production None
#    8.450 hand.chunk disc:1
#    8.450 B.chunk bot:None mid:None top:None
#    8.450 production move_to_A
#    8.500 production None
#    8.500 production move_to_A
#    8.550 production None
#    8.550 production move_to_A
#    8.600 production None
#    8.600 production move_to_A
#    8.650 production None
#    8.650 production move_to_B
#    8.700 production None
#    8.700 B.chunk bot:1 mid:None top:None
#    8.700 hand.chunk disc:None
#    8.700 production move_to_C
#    8.750 production None
#    8.750 production move_to_C
#    8.800 production None
#    8.800 production pick_from_C
#    8.850 production None
#    8.850 production move_to_C
#    8.900 production None
#    8.900 production pick_from_B
#    8.950 production None
#    8.950 hand.chunk disc:1
#    8.950 B.chunk bot:None mid:None top:None
#    8.950 production move_to_A
#    9.000 production None
#    9.000 production move_to_A
#    9.050 production None
#    9.050 production move_to_B
#    9.100 production None
#    9.100 B.chunk bot:1 mid:None top:None
#    9.100 hand.chunk disc:None
#    9.100 production move_to_C
#    9.150 production None
#    9.150 production move_to_C
#    9.200 production None
#    9.200 production move_to_A
#    9.250 production None
#    9.250 production move_to_A
#    9.300 production None
#    9.300 production pick_from_C
#    9.350 production None
#    9.350 production move_to_C
#    9.400 production None
#    9.400 production pick_from_B
#    9.450 production None
#    9.450 hand.chunk disc:1
#    9.450 B.chunk bot:None mid:None top:None
#    9.450 production move_to_A
#    9.500 production None
#    9.500 production move_to_B
#    9.550 production None
#    9.550 B.chunk bot:1 mid:None top:None
#    9.550 hand.chunk disc:None
#    9.550 production pick_from_B
#    9.600 production None
#    9.600 hand.chunk disc:1
#    9.600 B.chunk bot:None mid:None top:None
#    9.600 production move_to_B
#    9.650 production None
#    9.650 B.chunk bot:1 mid:None top:None
#    9.650 hand.chunk disc:None
#    9.650 production pick_from_A
#    9.700 production None
#    9.700 hand.chunk disc:3
#    9.700 A.chunk bot:2 mid:None top:None
#    9.700 production move_to_A
#    9.750 production None
#    9.750 A.chunk bot:2 mid:3 top:None
#    9.750 hand.chunk disc:None
#    9.750 production pick_from_C
#    9.800 production None
#    9.800 production move_to_C
#    9.850 production None
#    9.850 production move_to_B
#    9.900 production None
#    9.900 production move_to_A
#    9.950 production None
#    9.950 production move_to_C
#   10.000 production None
#   10.000 production pick_from_A
#   10.050 production None
#   10.050 hand.chunk disc:3
#   10.050 A.chunk bot:2 mid:None top:None
#   10.050 production move_to_C
#   10.100 production None
#   10.100 C.chunk bot:3 mid:None top:None
#   10.100 hand.chunk disc:None
#   10.100 production move_to_A
#   10.150 production None
#   10.150 production pick_from_A
#   10.200 production None
#   10.200 hand.chunk disc:2
#   10.200 A.chunk bot:None mid:None top:None
#   10.200 production move_to_C
#   10.250 production None
#   10.250 production move_to_A
#   10.300 production None
#   10.300 A.chunk bot:2 mid:None top:None
#   10.300 hand.chunk disc:None
#   10.300 production pick_from_A
#   10.350 production None
#   10.350 hand.chunk disc:2
#   10.350 A.chunk bot:None mid:None top:None
#   10.350 production move_to_A
#   10.400 production None
#   10.400 A.chunk bot:2 mid:None top:None
#   10.400 hand.chunk disc:None
#   10.400 production pick_from_A
#   10.450 production None
#   10.450 hand.chunk disc:2
#   10.450 A.chunk bot:None mid:None top:None
#   10.450 production move_to_A
#   10.500 production None
#   10.500 A.chunk bot:2 mid:None top:None
#   10.500 hand.chunk disc:None
#   10.500 production move_to_A
#   10.550 production None
#   10.550 production move_to_C
#   10.600 production None
#   10.600 production pick_from_C
#   10.650 production None
#   10.650 hand.chunk disc:3
#   10.650 C.chunk bot:None mid:None top:None
#   10.650 production move_to_A
#   10.700 production None
#   10.700 A.chunk bot:2 mid:3 top:None
#   10.700 hand.chunk disc:None
#   10.700 production move_to_B
#   10.750 production None
#   10.750 production pick_from_C
#   10.800 production None
#   10.800 production pick_from_C
#   10.850 production None
#   10.850 production move_to_B
#   10.900 production None
#   10.900 production move_to_B
#   10.950 production None
#   10.950 production move_to_B
#   11.000 production None
#   11.000 production move_to_A
#   11.050 production None
#   11.050 production pick_from_C
#   11.100 production None
#   11.100 production move_to_B
#   11.150 production None
#   11.150 production move_to_B
#   11.200 production None
#   11.200 production pick_from_A
#   11.250 production None
#   11.250 hand.chunk disc:3
#   11.250 A.chunk bot:2 mid:None top:None
#   11.250 production move_to_A
#   11.300 production None
#   11.300 A.chunk bot:2 mid:3 top:None
#   11.300 hand.chunk disc:None
#   11.300 production move_to_C
#   11.350 production None
#   11.350 production move_to_B
#   11.400 production None
#   11.400 production move_to_A
#   11.450 production None
#   11.450 production move_to_A
#   11.500 production None
#   11.500 production pick_from_B
#   11.550 production None
#   11.550 hand.chunk disc:1
#   11.550 B.chunk bot:None mid:None top:None
#   11.550 production move_to_A
#   11.600 production None
#   11.600 production move_to_C
#   11.650 production None
#   11.650 C.chunk bot:1 mid:None top:None
#   11.650 hand.chunk disc:None
#   11.650 production move_to_A
#   11.700 production None
#   11.700 production move_to_C
#   11.750 production None
#   11.750 production move_to_C
#   11.800 production None
#   11.800 production move_to_A
#   11.850 production None
#   11.850 production pick_from_C
#   11.900 production None
#   11.900 hand.chunk disc:1
#   11.900 C.chunk bot:None mid:None top:None
#   11.900 production move_to_A
#   11.950 production None
#   11.950 production move_to_C
#   12.000 production None
#   12.000 C.chunk bot:1 mid:None top:None
#   12.000 hand.chunk disc:None
#   12.000 production pick_from_B
#   12.050 production None
#   12.050 production move_to_B
#   12.100 production None
#   12.100 production move_to_A
#   12.150 production None
#   12.150 production pick_from_B
#   12.200 production None
#   12.200 production move_to_C
#   12.250 production None
#   12.250 production move_to_A
#   12.300 production None
#   12.300 production move_to_A
#   12.350 production None
#   12.350 production move_to_C
#   12.400 production None
#   12.400 production pick_from_B
#   12.450 production None
#   12.450 production move_to_A
#   12.500 production None
#   12.500 production move_to_C
#   12.550 production None
#   12.550 production pick_from_C
#   12.600 production None
#   12.600 hand.chunk disc:1
#   12.600 C.chunk bot:None mid:None top:None
#   12.600 production move_to_B
#   12.650 production None
#   12.650 B.chunk bot:1 mid:None top:None
#   12.650 hand.chunk disc:None
#   12.650 production move_to_C
#   12.700 production None
#   12.700 production move_to_B
#   12.750 production None
#   12.750 production pick_from_A
#   12.800 production None
#   12.800 hand.chunk disc:3
#   12.800 A.chunk bot:2 mid:None top:None
#   12.800 production move_to_C
#   12.850 production None
#   12.850 C.chunk bot:3 mid:None top:None
#   12.850 hand.chunk disc:None
#   12.850 production move_to_B
#   12.900 production None
#   12.900 production pick_from_A
#   12.950 production None
#   12.950 hand.chunk disc:2
#   12.950 A.chunk bot:None mid:None top:None
#   12.950 production move_to_C
#   13.000 production None
#   13.000 production move_to_B
#   13.050 production None
#   13.050 B.chunk bot:1 mid:2 top:None
#   13.050 hand.chunk disc:None
#   13.050 production pick_from_B
#   13.100 production None
#   13.100 hand.chunk disc:2
#   13.100 B.chunk bot:1 mid:None top:None
#   13.100 production move_to_C
#   13.150 production None
#   13.150 production move_to_C
#   13.200 production None
#   13.200 production move_to_B
#   13.250 production None
#   13.250 B.chunk bot:1 mid:2 top:None
#   13.250 hand.chunk disc:None
#   13.250 production move_to_B
#   13.300 production None
#   13.300 production pick_from_A
#   13.350 production None
#   13.350 production pick_from_C
#   13.400 production None
#   13.400 hand.chunk disc:3
#   13.400 C.chunk bot:None mid:None top:None
#   13.400 production move_to_A
#   13.450 production None
#   13.450 A.chunk bot:3 mid:None top:None
#   13.450 hand.chunk disc:None
#   13.450 production move_to_C
#   13.500 production None
#   13.500 production pick_from_B
#   13.550 production None
#   13.550 hand.chunk disc:2
#   13.550 B.chunk bot:1 mid:None top:None
#   13.550 production move_to_A
#   13.600 production None
#   13.600 production move_to_B
#   13.650 production None
#   13.650 B.chunk bot:1 mid:2 top:None
#   13.650 hand.chunk disc:None
#   13.650 production move_to_B
#   13.700 production None
#   13.700 production move_to_C
#   13.750 production None
#   13.750 production move_to_C
#   13.800 production None
#   13.800 production move_to_B
#   13.850 production None
#   13.850 production pick_from_B
#   13.900 production None
#   13.900 hand.chunk disc:2
#   13.900 B.chunk bot:1 mid:None top:None
#   13.900 production move_to_A
#   13.950 production None
#   13.950 production move_to_C
#   14.000 production None
#   14.000 C.chunk bot:2 mid:None top:None
#   14.000 hand.chunk disc:None
#   14.000 production move_to_B
#   14.050 production None
#   14.050 production move_to_C
#   14.100 production None
#   14.100 production move_to_C
#   14.150 production None
#   14.150 production move_to_C
#   14.200 production None
#   14.200 production pick_from_C
#   14.250 production None
#   14.250 hand.chunk disc:2
#   14.250 C.chunk bot:None mid:None top:None
#   14.250 production move_to_A
#   14.300 production None
#   14.300 production move_to_C
#   14.350 production None
#   14.350 C.chunk bot:2 mid:None top:None
#   14.350 hand.chunk disc:None
#   14.350 production move_to_A
#   14.400 production None
#   14.400 production move_to_A
#   14.450 production None
#   14.450 production pick_from_C
#   14.500 production None
#   14.500 hand.chunk disc:2
#   14.500 C.chunk bot:None mid:None top:None
#   14.500 production move_to_C
#   14.550 production None
#   14.550 C.chunk bot:2 mid:None top:None
#   14.550 hand.chunk disc:None
#   14.550 production pick_from_C
#   14.600 production None
#   14.600 hand.chunk disc:2
#   14.600 C.chunk bot:None mid:None top:None
#   14.600 production move_to_A
#   14.650 production None
#   14.650 production move_to_C
#   14.700 production None
#   14.700 C.chunk bot:2 mid:None top:None
#   14.700 hand.chunk disc:None
#   14.700 production pick_from_B
#   14.750 production None
#   14.750 hand.chunk disc:1
#   14.750 B.chunk bot:None mid:None top:None
#   14.750 production move_to_C
#   14.800 production None
#   14.800 production move_to_C
#   14.850 production None
#   14.850 production move_to_C
#   14.900 production None
#   14.900 production move_to_A
#   14.950 production None
#   14.950 production move_to_C
#   15.000 production None
#   15.000 production move_to_A
#   15.050 production None
#   15.050 production move_to_B
#   15.100 production None
#   15.100 B.chunk bot:1 mid:None top:None
#   15.100 hand.chunk disc:None
#   15.100 production move_to_B
#   15.150 production None
#   15.150 production pick_from_C
#   15.200 production None
#   15.200 hand.chunk disc:2
#   15.200 C.chunk bot:None mid:None top:None
#   15.200 production move_to_A
#   15.250 production None
#   15.250 production move_to_B
#   15.300 production None
#   15.300 B.chunk bot:1 mid:2 top:None
#   15.300 hand.chunk disc:None
#   15.300 production move_to_A
#   15.350 production None
#   15.350 production pick_from_B
#   15.400 production None
#   15.400 hand.chunk disc:2
#   15.400 B.chunk bot:1 mid:None top:None
#   15.400 production move_to_A
#   15.450 production None
#   15.450 production move_to_C
#   15.500 production None
#   15.500 C.chunk bot:2 mid:None top:None
#   15.500 hand.chunk disc:None
#   15.500 production move_to_A
#   15.550 production None
#   15.550 production move_to_C
#   15.600 production None
#   15.600 production pick_from_A
#   15.650 production None
#   15.650 hand.chunk disc:3
#   15.650 A.chunk bot:None mid:None top:None
#   15.650 production move_to_B
#   15.700 production None
#   15.700 B.chunk bot:1 mid:3 top:None
#   15.700 hand.chunk disc:None
#   15.700 production pick_from_A
#   15.750 production None
#   15.750 production move_to_B
#   15.800 production None
#   15.800 production pick_from_B
#   15.850 production None
#   15.850 hand.chunk disc:3
#   15.850 B.chunk bot:1 mid:None top:None
#   15.850 production move_to_B
#   15.900 production None
#   15.900 B.chunk bot:1 mid:3 top:None
#   15.900 hand.chunk disc:None
#   15.900 production pick_from_C
#   15.950 production None
#   15.950 hand.chunk disc:2
#   15.950 C.chunk bot:None mid:None top:None
#   15.950 production move_to_C
#   16.000 production None
#   16.000 C.chunk bot:2 mid:None top:None
#   16.000 hand.chunk disc:None
#   16.000 production move_to_B
#   16.050 production None
#   16.050 production pick_from_C
#   16.100 production None
#   16.100 hand.chunk disc:2
#   16.100 C.chunk bot:None mid:None top:None
#   16.100 production move_to_A
#   16.150 production None
#   16.150 A.chunk bot:2 mid:None top:None
#   16.150 hand.chunk disc:None
#   16.150 production pick_from_C
#   16.200 production None
#   16.200 production pick_from_C
#   16.250 production None
#   16.250 production move_to_C
#   16.300 production None
#   16.300 production pick_from_C
#   16.350 production None
#   16.350 production pick_from_A
#   16.400 production None
#   16.400 hand.chunk disc:2
#   16.400 A.chunk bot:None mid:None top:None
#   16.400 production move_to_C
#   16.450 production None
#   16.450 C.chunk bot:2 mid:None top:None
#   16.450 hand.chunk disc:None
#   16.450 production pick_from_C
#   16.500 production None
#   16.500 hand.chunk disc:2
#   16.500 C.chunk bot:None mid:None top:None
#   16.500 production move_to_A
#   16.550 production None
#   16.550 A.chunk bot:2 mid:None top:None
#   16.550 hand.chunk disc:None
#   16.550 production move_to_C
#   16.600 production None
#   16.600 production pick_from_B
#   16.650 production None
#   16.650 hand.chunk disc:3
#   16.650 B.chunk bot:1 mid:None top:None
#   16.650 production move_to_A
#   16.700 production None
#   16.700 A.chunk bot:2 mid:3 top:None
#   16.700 hand.chunk disc:None
#   16.700 production pick_from_B
#   16.750 production None
#   16.750 hand.chunk disc:1
#   16.750 B.chunk bot:None mid:None top:None
#   16.750 production move_to_B
#   16.800 production None
#   16.800 B.chunk bot:1 mid:None top:None
#   16.800 hand.chunk disc:None
#   16.800 production pick_from_B
#   16.850 production None
#   16.850 hand.chunk disc:1
#   16.850 B.chunk bot:None mid:None top:None
#   16.850 production move_to_C
#   16.900 production None
#   16.900 C.chunk bot:1 mid:None top:None
#   16.900 hand.chunk disc:None
#   16.900 production move_to_C
#   16.950 production None
#   16.950 production move_to_C
#   17.000 production None
#   17.000 production pick_from_C
#   17.050 production None
#   17.050 hand.chunk disc:1
#   17.050 C.chunk bot:None mid:None top:None
#   17.050 production move_to_B
#   17.100 production None
#   17.100 B.chunk bot:1 mid:None top:None
#   17.100 hand.chunk disc:None
#   17.100 production move_to_A
#   17.150 production None
#   17.150 production pick_from_A
#   17.200 production None
#   17.200 hand.chunk disc:3
#   17.200 A.chunk bot:2 mid:None top:None
#   17.200 production move_to_B
#   17.250 production None
#   17.250 B.chunk bot:1 mid:3 top:None
#   17.250 hand.chunk disc:None
#   17.250 production move_to_B
#   17.300 production None
#   17.300 production pick_from_C
#   17.350 production None
#   17.350 production pick_from_A
#   17.400 production None
#   17.400 hand.chunk disc:2
#   17.400 A.chunk bot:None mid:None top:None
#   17.400 production move_to_C
#   17.450 production None
#   17.450 C.chunk bot:2 mid:None top:None
#   17.450 hand.chunk disc:None
#   17.450 production move_to_A
#   17.500 production None
#   17.500 production pick_from_A
#   17.550 production None
#   17.550 production move_to_B
#   17.600 production None
#   17.600 production move_to_A
#   17.650 production None
#   17.650 production pick_from_C
#   17.700 production None
#   17.700 hand.chunk disc:2
#   17.700 C.chunk bot:None mid:None top:None
#   17.700 production move_to_C
#   17.750 production None
#   17.750 C.chunk bot:2 mid:None top:None
#   17.750 hand.chunk disc:None
#   17.750 production pick_from_B
#   17.800 production None
#   17.800 hand.chunk disc:3
#   17.800 B.chunk bot:1 mid:None top:None
#   17.800 production move_to_C
#   17.850 production None
#   17.850 C.chunk bot:2 mid:3 top:None
#   17.850 hand.chunk disc:None
#   17.850 production pick_from_B
#   17.900 production None
#   17.900 hand.chunk disc:1
#   17.900 B.chunk bot:None mid:None top:None
#   17.900 production move_to_C
#   17.950 production None
#   17.950 production move_to_B
#   18.000 production None
#   18.000 B.chunk bot:1 mid:None top:None
#   18.000 hand.chunk disc:None
#   18.000 production pick_from_C
#   18.050 production None
#   18.050 hand.chunk disc:3
#   18.050 C.chunk bot:2 mid:None top:None
#   18.050 production move_to_A
#   18.100 production None
#   18.100 A.chunk bot:3 mid:None top:None
#   18.100 hand.chunk disc:None
#   18.100 production move_to_B
#   18.150 production None
#   18.150 production move_to_C
#   18.200 production None
#   18.200 production move_to_B
#   18.250 production None
#   18.250 production pick_from_C
#   18.300 production None
#   18.300 hand.chunk disc:2
#   18.300 C.chunk bot:None mid:None top:None
#   18.300 production move_to_A
#   18.350 production None
#   18.350 production move_to_B
#   18.400 production None
#   18.400 B.chunk bot:1 mid:2 top:None
#   18.400 hand.chunk disc:None
#   18.400 production move_to_C
#   18.450 production None
#   18.450 production pick_from_C
#   18.500 production None
#   18.500 production pick_from_C
#   18.550 production None
#   18.550 production pick_from_B
#   18.600 production None
#   18.600 hand.chunk disc:2
#   18.600 B.chunk bot:1 mid:None top:None
#   18.600 production move_to_B
#   18.650 production None
#   18.650 B.chunk bot:1 mid:2 top:None
#   18.650 hand.chunk disc:None
#   18.650 production pick_from_C
#   18.700 production None
#   18.700 production pick_from_A
#   18.750 production None
#   18.750 hand.chunk disc:3
#   18.750 A.chunk bot:None mid:None top:None
#   18.750 production move_to_A
#   18.800 production None
#   18.800 A.chunk bot:3 mid:None top:None
#   18.800 hand.chunk disc:None
#   18.800 production pick_from_A
#   18.850 production None
#   18.850 hand.chunk disc:3
#   18.850 A.chunk bot:None mid:None top:None
#   18.850 production move_to_A
#   18.900 production None
#   18.900 A.chunk bot:3 mid:None top:None
#   18.900 hand.chunk disc:None
#   18.900 production pick_from_A
#   18.950 production None
#   18.950 hand.chunk disc:3
#   18.950 A.chunk bot:None mid:None top:None
#   18.950 production move_to_C
#   19.000 production None
#   19.000 C.chunk bot:3 mid:None top:None
#   19.000 hand.chunk disc:None
#   19.000 production move_to_B
#   19.050 production None
#   19.050 production move_to_B
#   19.100 production None
#   19.100 production move_to_C
#   19.150 production None
#   19.150 production move_to_A
#   19.200 production None
#   19.200 production move_to_C
#   19.250 production None
#   19.250 production pick_from_C
#   19.300 production None
#   19.300 hand.chunk disc:3
#   19.300 C.chunk bot:None mid:None top:None
#   19.300 production move_to_A
#   19.350 production None
#   19.350 A.chunk bot:3 mid:None top:None
#   19.350 hand.chunk disc:None
#   19.350 production move_to_A
#   19.400 production None
#   19.400 production pick_from_C
#   19.450 production None
#   19.450 production pick_from_C
#   19.500 production None
#   19.500 production pick_from_C
#   19.550 production None
#   19.550 production move_to_A
#   19.600 production None
#   19.600 production move_to_C
#   19.650 production None
#   19.650 production pick_from_A
#   19.700 production None
#   19.700 hand.chunk disc:3
#   19.700 A.chunk bot:None mid:None top:None
#   19.700 production move_to_B
#   19.750 production None
#   19.750 B.chunk bot:1 mid:2 top:3
#   19.750 hand.chunk disc:None
#   19.750 production pick_from_B
#   19.800 production None
#   19.800 hand.chunk disc:3
#   19.800 B.chunk bot:1 mid:2 top:None
#   19.800 production move_to_C
#   19.850 production None
#   19.850 C.chunk bot:3 mid:None top:None
#   19.850 hand.chunk disc:None
#   19.850 production pick_from_A
#   19.900 production None
#   19.900 production move_to_B
#   19.950 production None
#   19.950 production move_to_B
#   20.000 production None
#   20.000 production pick_from_C
#   20.050 production None
#   20.050 hand.chunk disc:3
#   20.050 C.chunk bot:None mid:None top:None
#   20.050 production move_to_A
#   20.100 production None
#   20.100 A.chunk bot:3 mid:None top:None
#   20.100 hand.chunk disc:None
#   20.100 production pick_from_B
#   20.150 production None
#   20.150 hand.chunk disc:2
#   20.150 B.chunk bot:1 mid:None top:None
#   20.150 production move_to_C
#   20.200 production None
#   20.200 C.chunk bot:2 mid:None top:None
#   20.200 hand.chunk disc:None
#   20.200 production move_to_C
#   20.250 production None
#   20.250 production pick_from_C
#   20.300 production None
#   20.300 hand.chunk disc:2
#   20.300 C.chunk bot:None mid:None top:None
#   20.300 production move_to_B
#   20.350 production None
#   20.350 B.chunk bot:1 mid:2 top:None
#   20.350 hand.chunk disc:None
#   20.350 production pick_from_C
#   20.400 production None
#   20.400 production move_to_B
#   20.450 production None
#   20.450 production move_to_C
#   20.500 production None
#   20.500 production pick_from_B
#   20.550 production None
#   20.550 hand.chunk disc:2
#   20.550 B.chunk bot:1 mid:None top:None
#   20.550 production move_to_B
#   20.600 production None
#   20.600 B.chunk bot:1 mid:2 top:None
#   20.600 hand.chunk disc:None
#   20.600 production move_to_B
#   20.650 production None
#   20.650 production move_to_B
#   20.700 production None
#   20.700 production move_to_C
#   20.750 production None
#   20.750 production pick_from_A
#   20.800 production None
#   20.800 hand.chunk disc:3
#   20.800 A.chunk bot:None mid:None top:None
#   20.800 production move_to_C
#   20.850 production None
#   20.850 C.chunk bot:3 mid:None top:None
#   20.850 hand.chunk disc:None
#   20.850 production move_to_B
#   20.900 production None
#   20.900 production move_to_C
#   20.950 production None
#   20.950 production move_to_A
#   21.000 production None
#   21.000 production pick_from_A
#   21.050 production None
#   21.050 production move_to_B
#   21.100 production None
#   21.100 production pick_from_A
#   21.150 production None
#   21.150 production move_to_A
#   21.200 production None
#   21.200 production move_to_A
#   21.250 production None
#   21.250 production pick_from_A
#   21.300 production None
#   21.300 production pick_from_B
#   21.350 production None
#   21.350 hand.chunk disc:2
#   21.350 B.chunk bot:1 mid:None top:None
#   21.350 production move_to_A
#   21.400 production None
#   21.400 A.chunk bot:2 mid:None top:None
#   21.400 hand.chunk disc:None
#   21.400 production pick_from_C
#   21.450 production None
#   21.450 hand.chunk disc:3
#   21.450 C.chunk bot:None mid:None top:None
#   21.450 production move_to_B
#   21.500 production None
#   21.500 B.chunk bot:1 mid:3 top:None
#   21.500 hand.chunk disc:None
#   21.500 production move_to_B
#   21.550 production None
#   21.550 production move_to_C
#   21.600 production None
#   21.600 production move_to_C
#   21.650 production None
#   21.650 production move_to_A
#   21.700 production None
#   21.700 production move_to_A
#   21.750 production None
#   21.750 production pick_from_B
#   21.800 production None
#   21.800 hand.chunk disc:3
#   21.800 B.chunk bot:1 mid:None top:None
#   21.800 production move_to_B
#   21.850 production None
#   21.850 B.chunk bot:1 mid:3 top:None
#   21.850 hand.chunk disc:None
#   21.850 production pick_from_B
#   21.900 production None
#   21.900 hand.chunk disc:3
#   21.900 B.chunk bot:1 mid:None top:None
#   21.900 production move_to_A
#   21.950 production None
#   21.950 A.chunk bot:2 mid:3 top:None
#   21.950 hand.chunk disc:None
#   21.950 production move_to_C
#   22.000 production None
#   22.000 production pick_from_A
#   22.050 production None
#   22.050 hand.chunk disc:3
#   22.050 A.chunk bot:2 mid:None top:None
#   22.050 production move_to_A
#   22.100 production None
#   22.100 A.chunk bot:2 mid:3 top:None
#   22.100 hand.chunk disc:None
#   22.100 production move_to_A
#   22.150 production None
#   22.150 production pick_from_A
#   22.200 production None
#   22.200 hand.chunk disc:3
#   22.200 A.chunk bot:2 mid:None top:None
#   22.200 production move_to_C
#   22.250 production None
#   22.250 C.chunk bot:3 mid:None top:None
#   22.250 hand.chunk disc:None
#   22.250 production move_to_A
#   22.300 production None
#   22.300 production move_to_A
#   22.350 production None
#   22.350 production move_to_A
#   22.400 production None
#   22.400 production pick_from_B
#   22.450 production None
#   22.450 hand.chunk disc:1
#   22.450 B.chunk bot:None mid:None top:None
#   22.450 production move_to_A
#   22.500 production None
#   22.500 production move_to_B
#   22.550 production None
#   22.550 B.chunk bot:1 mid:None top:None
#   22.550 hand.chunk disc:None
#   22.550 production move_to_A
#   22.600 production None
#   22.600 production pick_from_A
#   22.650 production None
#   22.650 hand.chunk disc:2
#   22.650 A.chunk bot:None mid:None top:None
#   22.650 production move_to_C
#   22.700 production None
#   22.700 production move_to_C
#   22.750 production None
#   22.750 production move_to_A
#   22.800 production None
#   22.800 A.chunk bot:2 mid:None top:None
#   22.800 hand.chunk disc:None
#   22.800 production move_to_B
#   22.850 production None
#   22.850 production move_to_A
#   22.900 production None
#   22.900 production pick_from_A
#   22.950 production None
#   22.950 hand.chunk disc:2
#   22.950 A.chunk bot:None mid:None top:None
#   22.950 production move_to_A
#   23.000 production None
#   23.000 A.chunk bot:2 mid:None top:None
#   23.000 hand.chunk disc:None
#   23.000 production move_to_A
#   23.050 production None
#   23.050 production move_to_C
#   23.100 production None
#   23.100 production pick_from_A
#   23.150 production None
#   23.150 hand.chunk disc:2
#   23.150 A.chunk bot:None mid:None top:None
#   23.150 production move_to_B
#   23.200 production None
#   23.200 B.chunk bot:1 mid:2 top:None
#   23.200 hand.chunk disc:None
#   23.200 production pick_from_C
#   23.250 production None
#   23.250 hand.chunk disc:3
#   23.250 C.chunk bot:None mid:None top:None
#   23.250 production move_to_C
#   23.300 production None
#   23.300 C.chunk bot:3 mid:None top:None
#   23.300 hand.chunk disc:None
#   23.300 production pick_from_B
#   23.350 production None
#   23.350 hand.chunk disc:2
#   23.350 B.chunk bot:1 mid:None top:None
#   23.350 production move_to_B
#   23.400 production None
#   23.400 B.chunk bot:1 mid:2 top:None
#   23.400 hand.chunk disc:None
#   23.400 production pick_from_B
#   23.450 production None
#   23.450 hand.chunk disc:2
#   23.450 B.chunk bot:1 mid:None top:None
#   23.450 production move_to_B
#   23.500 production None
#   23.500 B.chunk bot:1 mid:2 top:None
#   23.500 hand.chunk disc:None
#   23.500 production move_to_A
#   23.550 production None
#   23.550 production pick_from_A
#   23.600 production None
#   23.600 production pick_from_C
#   23.650 production None
#   23.650 hand.chunk disc:3
#   23.650 C.chunk bot:None mid:None top:None
#   23.650 production move_to_A
#   23.700 production None
#   23.700 A.chunk bot:3 mid:None top:None
#   23.700 hand.chunk disc:None
#   23.700 production pick_from_A
#   23.750 production None
#   23.750 hand.chunk disc:3
#   23.750 A.chunk bot:None mid:None top:None
#   23.750 production move_to_C
#   23.800 production None
#   23.800 C.chunk bot:3 mid:None top:None
#   23.800 hand.chunk disc:None
#   23.800 production move_to_C
#   23.850 production None
#   23.850 production pick_from_A
#   23.900 production None
#   23.900 production move_to_B
#   23.950 production None
#   23.950 production pick_from_B
#   24.000 production None
#   24.000 hand.chunk disc:2
#   24.000 B.chunk bot:1 mid:None top:None
#   24.000 production move_to_B
#   24.050 production None
#   24.050 B.chunk bot:1 mid:2 top:None
#   24.050 hand.chunk disc:None
#   24.050 production pick_from_C
#   24.100 production None
#   24.100 hand.chunk disc:3
#   24.100 C.chunk bot:None mid:None top:None
#   24.100 production move_to_C
#   24.150 production None
#   24.150 C.chunk bot:3 mid:None top:None
#   24.150 hand.chunk disc:None
#   24.150 production pick_from_B
#   24.200 production None
#   24.200 hand.chunk disc:2
#   24.200 B.chunk bot:1 mid:None top:None
#   24.200 production move_to_B
#   24.250 production None
#   24.250 B.chunk bot:1 mid:2 top:None
#   24.250 hand.chunk disc:None
#   24.250 production pick_from_A
#   24.300 production None
#   24.300 production move_to_C
#   24.350 production None
#   24.350 production pick_from_C
#   24.400 production None
#   24.400 hand.chunk disc:3
#   24.400 C.chunk bot:None mid:None top:None
#   24.400 production move_to_C
#   24.450 production None
#   24.450 C.chunk bot:3 mid:None top:None
#   24.450 hand.chunk disc:None
#   24.450 production move_to_B
#   24.500 production None
#   24.500 production move_to_A
#   24.550 production None
#   24.550 production move_to_B
#   24.600 production None
#   24.600 production move_to_A
#   24.650 production None
#   24.650 production pick_from_B
#   24.700 production None
#   24.700 hand.chunk disc:2
#   24.700 B.chunk bot:1 mid:None top:None
#   24.700 production move_to_A
#   24.750 production None
#   24.750 A.chunk bot:2 mid:None top:None
#   24.750 hand.chunk disc:None
#   24.750 production move_to_B
#   24.800 production None
#   24.800 production pick_from_A
#   24.850 production None
#   24.850 hand.chunk disc:2
#   24.850 A.chunk bot:None mid:None top:None
#   24.850 production move_to_C
#   24.900 production None
#   24.900 production move_to_B
#   24.950 production None
#   24.950 B.chunk bot:1 mid:2 top:None
#   24.950 hand.chunk disc:None
#   24.950 production move_to_C
#   25.000 production None
#   25.000 production pick_from_B
#   25.050 production None
#   25.050 hand.chunk disc:2
#   25.050 B.chunk bot:1 mid:None top:None
#   25.050 production move_to_A
#   25.100 production None
#   25.100 A.chunk bot:2 mid:None top:None
#   25.100 hand.chunk disc:None
#   25.100 production pick_from_A
#   25.150 production None
#   25.150 hand.chunk disc:2
#   25.150 A.chunk bot:None mid:None top:None
#   25.150 production move_to_A
#   25.200 production None
#   25.200 A.chunk bot:2 mid:None top:None
#   25.200 hand.chunk disc:None
#   25.200 production move_to_A
#   25.250 production None
#   25.250 production pick_from_C
#   25.300 production None
#   25.300 hand.chunk disc:3
#   25.300 C.chunk bot:None mid:None top:None
#   25.300 production move_to_B
#   25.350 production None
#   25.350 B.chunk bot:1 mid:3 top:None
#   25.350 hand.chunk disc:None
#   25.350 production pick_from_B
#   25.400 production None
#   25.400 hand.chunk disc:3
#   25.400 B.chunk bot:1 mid:None top:None
#   25.400 production move_to_A
#   25.450 production None
#   25.450 A.chunk bot:2 mid:3 top:None
#   25.450 hand.chunk disc:None
#   25.450 production move_to_A
#   25.500 production None
#   25.500 production pick_from_C
#   25.550 production None
#   25.550 production move_to_A
#   25.600 production None
#   25.600 production move_to_C
#   25.650 production None
#   25.650 production move_to_C
#   25.700 production None
#   25.700 production pick_from_B
#   25.750 production None
#   25.750 hand.chunk disc:1
#   25.750 B.chunk bot:None mid:None top:None
#   25.750 production move_to_B
#   25.800 production None
#   25.800 B.chunk bot:1 mid:None top:None
#   25.800 hand.chunk disc:None
#   25.800 production pick_from_C
#   25.850 production None
#   25.850 production move_to_A
#   25.900 production None
#   25.900 production pick_from_A
#   25.950 production None
#   25.950 hand.chunk disc:3
#   25.950 A.chunk bot:2 mid:None top:None
#   25.950 production move_to_B
#   26.000 production None
#   26.000 B.chunk bot:1 mid:3 top:None
#   26.000 hand.chunk disc:None
#   26.000 production pick_from_B
#   26.050 production None
#   26.050 hand.chunk disc:3
#   26.050 B.chunk bot:1 mid:None top:None
#   26.050 production move_to_C
#   26.100 production None
#   26.100 C.chunk bot:3 mid:None top:None
#   26.100 hand.chunk disc:None
#   26.100 production pick_from_C
#   26.150 production None
#   26.150 hand.chunk disc:3
#   26.150 C.chunk bot:None mid:None top:None
#   26.150 production move_to_A
#   26.200 production None
#   26.200 A.chunk bot:2 mid:3 top:None
#   26.200 hand.chunk disc:None
#   26.200 production move_to_A
#   26.250 production None
#   26.250 production pick_from_A
#   26.300 production None
#   26.300 hand.chunk disc:3
#   26.300 A.chunk bot:2 mid:None top:None
#   26.300 production move_to_C
#   26.350 production None
#   26.350 C.chunk bot:3 mid:None top:None
#   26.350 hand.chunk disc:None
#   26.350 production pick_from_C
#   26.400 production None
#   26.400 hand.chunk disc:3
#   26.400 C.chunk bot:None mid:None top:None
#   26.400 production move_to_A
#   26.450 production None
#   26.450 A.chunk bot:2 mid:3 top:None
#   26.450 hand.chunk disc:None
#   26.450 production pick_from_A
#   26.500 production None
#   26.500 hand.chunk disc:3
#   26.500 A.chunk bot:2 mid:None top:None
#   26.500 production move_to_A
#   26.550 production None
#   26.550 A.chunk bot:2 mid:3 top:None
#   26.550 hand.chunk disc:None
#   26.550 production pick_from_B
#   26.600 production None
#   26.600 hand.chunk disc:1
#   26.600 B.chunk bot:None mid:None top:None
#   26.600 production move_to_C
#   26.650 production None
#   26.650 C.chunk bot:1 mid:None top:None
#   26.650 hand.chunk disc:None
# ...
#   60.400 production None
#   60.400 A.chunk bot:3 mid:None top:None
#   60.400 hand.chunk disc:None
#   60.400 production move_to_B
#   60.450 production None
#   60.450 production move_to_A
#   60.500 production None
#   60.500 production move_to_C
#   60.550 production None
#   60.550 production move_to_A
#   60.600 production None
#   60.600 production pick_from_B
#   60.650 production None
#   60.650 hand.chunk disc:2
#   60.650 B.chunk bot:None mid:None top:None
#   60.650 production move_to_C
#   60.700 production None
#   60.700 C.chunk bot:1 mid:2 top:None
#   60.700 hand.chunk disc:None
#   60.700 production move_to_C
#   60.750 production None
#   60.750 production move_to_B
#   60.800 production None
#   60.800 production pick_from_B
#   60.850 production None
#   60.850 production move_to_C
#   60.900 production None
#   60.900 production pick_from_B
#   60.950 production None
#   60.950 production pick_from_C
#   61.000 production None
#   61.000 hand.chunk disc:2
#   61.000 C.chunk bot:1 mid:None top:None
#   61.000 production move_to_B
#   61.050 production None
#   61.050 B.chunk bot:2 mid:None top:None
#   61.050 hand.chunk disc:None
#   61.050 production move_to_C
#   61.100 production None
#   61.100 production pick_from_C
#   61.150 production None
#   61.150 hand.chunk disc:1
#   61.150 C.chunk bot:None mid:None top:None
#   61.150 production move_to_B
#   61.200 production None
#   61.200 production move_to_B
#   61.250 production None
#   61.250 production move_to_B
#   61.300 production None
#   61.300 production move_to_B
#   61.350 production None
#   61.350 production move_to_B
#   61.400 production None
#   61.400 production move_to_A
#   61.450 production None
#   61.450 production move_to_B
#   61.500 production None
#   61.500 production move_to_B
#   61.550 production None
#   61.550 production move_to_C
#   61.600 production None
#   61.600 C.chunk bot:1 mid:None top:None
#   61.600 hand.chunk disc:None
#   61.600 production move_to_C
#   61.650 production None
#   61.650 production move_to_B
#   61.700 production None
#   61.700 production pick_from_A
#   61.750 production None
#   61.750 hand.chunk disc:3
#   61.750 A.chunk bot:None mid:None top:None
#   61.750 production move_to_C
#   61.800 production None
#   61.800 C.chunk bot:1 mid:3 top:None
#   61.800 hand.chunk disc:None
#   61.800 production move_to_A
#   61.850 production None
#   61.850 production pick_from_B
#   61.900 production None
#   61.900 hand.chunk disc:2
#   61.900 B.chunk bot:None mid:None top:None
#   61.900 production move_to_C
#   61.950 production None
#   61.950 production move_to_A
#   62.000 production None
#   62.000 A.chunk bot:2 mid:None top:None
#   62.000 hand.chunk disc:None
#   62.000 production pick_from_B
#   62.050 production None
#   62.050 production move_to_A
#   62.100 production None
#   62.100 production move_to_B
#   62.150 production None
#   62.150 production move_to_B
#   62.200 production None
#   62.200 production pick_from_A
#   62.250 production None
#   62.250 hand.chunk disc:2
#   62.250 A.chunk bot:None mid:None top:None
#   62.250 production move_to_B
#   62.300 production None
#   62.300 B.chunk bot:2 mid:None top:None
#   62.300 hand.chunk disc:None
#   62.300 production move_to_B
#   62.350 production None
#   62.350 production pick_from_C
#   62.400 production None
#   62.400 hand.chunk disc:3
#   62.400 C.chunk bot:1 mid:None top:None
#   62.400 production move_to_A
#   62.450 production None
#   62.450 A.chunk bot:3 mid:None top:None
#   62.450 hand.chunk disc:None
#   62.450 production pick_from_A
#   62.500 production None
#   62.500 hand.chunk disc:3
#   62.500 A.chunk bot:None mid:None top:None
#   62.500 production move_to_A
#   62.550 production None
#   62.550 A.chunk bot:3 mid:None top:None
#   62.550 hand.chunk disc:None
#   62.550 production pick_from_B
#   62.600 production None
#   62.600 hand.chunk disc:2
#   62.600 B.chunk bot:None mid:None top:None
#   62.600 production move_to_B
#   62.650 production None
#   62.650 B.chunk bot:2 mid:None top:None
#   62.650 hand.chunk disc:None
#   62.650 production pick_from_C
#   62.700 production None
#   62.700 hand.chunk disc:1
#   62.700 C.chunk bot:None mid:None top:None
#   62.700 production move_to_A
#   62.750 production None
#   62.750 production move_to_A
#   62.800 production None
#   62.800 production move_to_C
#   62.850 production None
#   62.850 C.chunk bot:1 mid:None top:None
#   62.850 hand.chunk disc:None
#   62.850 production pick_from_C
#   62.900 production None
#   62.900 hand.chunk disc:1
#   62.900 C.chunk bot:None mid:None top:None
#   62.900 production move_to_B
#   62.950 production None
#   62.950 production move_to_C
#   63.000 production None
#   63.000 C.chunk bot:1 mid:None top:None
#   63.000 hand.chunk disc:None
#   63.000 production pick_from_B
#   63.050 production None
#   63.050 hand.chunk disc:2
#   63.050 B.chunk bot:None mid:None top:None
#   63.050 production move_to_C
#   63.100 production None
#   63.100 C.chunk bot:1 mid:2 top:None
#   63.100 hand.chunk disc:None
#   63.100 production pick_from_C
#   63.150 production None
#   63.150 hand.chunk disc:2
#   63.150 C.chunk bot:1 mid:None top:None
#   63.150 production move_to_A
#   63.200 production None
#   63.200 production move_to_A
#   63.250 production None
#   63.250 production move_to_A
#   63.300 production None
#   63.300 production move_to_A
#   63.350 production None
#   63.350 production move_to_A
#   63.400 production None
#   63.400 production move_to_C
#   63.450 production None
#   63.450 C.chunk bot:1 mid:2 top:None
#   63.450 hand.chunk disc:None
#   63.450 production move_to_B
#   63.500 production None
#   63.500 production pick_from_A
#   63.550 production None
#   63.550 hand.chunk disc:3
#   63.550 A.chunk bot:None mid:None top:None
#   63.550 production move_to_A
#   63.600 production None
#   63.600 A.chunk bot:3 mid:None top:None
#   63.600 hand.chunk disc:None
#   63.600 production move_to_A
#   63.650 production None
#   63.650 production pick_from_A
#   63.700 production None
#   63.700 hand.chunk disc:3
#   63.700 A.chunk bot:None mid:None top:None
#   63.700 production move_to_A
#   63.750 production None
#   63.750 A.chunk bot:3 mid:None top:None
#   63.750 hand.chunk disc:None
#   63.750 production move_to_B
#   63.800 production None
#   63.800 production move_to_A
#   63.850 production None
#   63.850 production pick_from_C
#   63.900 production None
#   63.900 hand.chunk disc:2
#   63.900 C.chunk bot:1 mid:None top:None
#   63.900 production move_to_B
#   63.950 production None
#   63.950 B.chunk bot:2 mid:None top:None
#   63.950 hand.chunk disc:None
#   63.950 production pick_from_C
#   64.000 production None
#   64.000 hand.chunk disc:1
#   64.000 C.chunk bot:None mid:None top:None
#   64.000 production move_to_C
#   64.050 production None
#   64.050 C.chunk bot:1 mid:None top:None
#   64.050 hand.chunk disc:None
#   64.050 production move_to_B
#   64.100 production None
#   64.100 production move_to_B
#   64.150 production None
#   64.150 production pick_from_A
#   64.200 production None
#   64.200 hand.chunk disc:3
#   64.200 A.chunk bot:None mid:None top:None
#   64.200 production move_to_A
#   64.250 production None
#   64.250 A.chunk bot:3 mid:None top:None
#   64.250 hand.chunk disc:None
#   64.250 production move_to_C
#   64.300 production None
#   64.300 production move_to_C
#   64.350 production None
#   64.350 production pick_from_B
#   64.400 production None
#   64.400 hand.chunk disc:2
#   64.400 B.chunk bot:None mid:None top:None
#   64.400 production move_to_B
#   64.450 production None
#   64.450 B.chunk bot:2 mid:None top:None
#   64.450 hand.chunk disc:None
#   64.450 production move_to_A
#   64.500 production None
#   64.500 production pick_from_C
#   64.550 production None
#   64.550 hand.chunk disc:1
#   64.550 C.chunk bot:None mid:None top:None
#   64.550 production move_to_B
#   64.600 production None
#   64.600 production move_to_C
#   64.650 production None
#   64.650 C.chunk bot:1 mid:None top:None
#   64.650 hand.chunk disc:None
#   64.650 production pick_from_A
#   64.700 production None
#   64.700 hand.chunk disc:3
#   64.700 A.chunk bot:None mid:None top:None
#   64.700 production move_to_C
#   64.750 production None
#   64.750 C.chunk bot:1 mid:3 top:None
#   64.750 hand.chunk disc:None
#   64.750 production move_to_C
#   64.800 production None
#   64.800 production pick_from_B
#   64.850 production None
#   64.850 hand.chunk disc:2
#   64.850 B.chunk bot:None mid:None top:None
#   64.850 production move_to_B
#   64.900 production None
#   64.900 B.chunk bot:2 mid:None top:None
#   64.900 hand.chunk disc:None
#   64.900 production move_to_B
#   64.950 production None
#   64.950 production move_to_B
#   65.000 production None
#   65.000 production move_to_C
#   65.050 production None
#   65.050 production move_to_C
#   65.100 production None
#   65.100 production move_to_C
#   65.150 production None
#   65.150 production pick_from_C
#   65.200 production None
#   65.200 hand.chunk disc:3
#   65.200 C.chunk bot:1 mid:None top:None
#   65.200 production move_to_C
#   65.250 production None
#   65.250 C.chunk bot:1 mid:3 top:None
#   65.250 hand.chunk disc:None
#   65.250 production pick_from_C
#   65.300 production None
#   65.300 hand.chunk disc:3
#   65.300 C.chunk bot:1 mid:None top:None
#   65.300 production move_to_C
#   65.350 production None
#   65.350 C.chunk bot:1 mid:3 top:None
#   65.350 hand.chunk disc:None
#   65.350 production move_to_A
#   65.400 production None
#   65.400 production move_to_C
#   65.450 production None
#   65.450 production move_to_B
#   65.500 production None
#   65.500 production pick_from_C
#   65.550 production None
#   65.550 hand.chunk disc:3
#   65.550 C.chunk bot:1 mid:None top:None
#   65.550 production move_to_B
#   65.600 production None
#   65.600 B.chunk bot:2 mid:3 top:None
#   65.600 hand.chunk disc:None
#   65.600 production move_to_C
#   65.650 production None
#   65.650 production pick_from_B
#   65.700 production None
#   65.700 hand.chunk disc:3
#   65.700 B.chunk bot:2 mid:None top:None
#   65.700 production move_to_C
#   65.750 production None
#   65.750 C.chunk bot:1 mid:3 top:None
#   65.750 hand.chunk disc:None
#   65.750 production pick_from_C
#   65.800 production None
#   65.800 hand.chunk disc:3
#   65.800 C.chunk bot:1 mid:None top:None
#   65.800 production move_to_A
#   65.850 production None
#   65.850 A.chunk bot:3 mid:None top:None
#   65.850 hand.chunk disc:None
#   65.850 production move_to_A
#   65.900 production None
#   65.900 production pick_from_B
#   65.950 production None
#   65.950 hand.chunk disc:2
#   65.950 B.chunk bot:None mid:None top:None
#   65.950 production move_to_A
#   66.000 production None
#   66.000 production move_to_A
#   66.050 production None
#   66.050 production move_to_B
#   66.100 production None
#   66.100 B.chunk bot:2 mid:None top:None
#   66.100 hand.chunk disc:None
#   66.100 production move_to_A
#   66.150 production None
#   66.150 production move_to_A
#   66.200 production None
#   66.200 production pick_from_B
#   66.250 production None
#   66.250 hand.chunk disc:2
#   66.250 B.chunk bot:None mid:None top:None
#   66.250 production move_to_C
#   66.300 production None
#   66.300 C.chunk bot:1 mid:2 top:None
#   66.300 hand.chunk disc:None
#   66.300 production pick_from_C
#   66.350 production None
#   66.350 hand.chunk disc:2
#   66.350 C.chunk bot:1 mid:None top:None
#   66.350 production move_to_A
#   66.400 production None
#   66.400 production move_to_B
#   66.450 production None
#   66.450 B.chunk bot:2 mid:None top:None
#   66.450 hand.chunk disc:None
#   66.450 production move_to_A
#   66.500 production None
#   66.500 production move_to_C
#   66.550 production None
#   66.550 production pick_from_B
#   66.600 production None
#   66.600 hand.chunk disc:2
#   66.600 B.chunk bot:None mid:None top:None
#   66.600 production move_to_A
#   66.650 production None
#   66.650 production move_to_B
#   66.700 production None
#   66.700 B.chunk bot:2 mid:None top:None
#   66.700 hand.chunk disc:None
#   66.700 production move_to_A
#   66.750 production None
#   66.750 production pick_from_B
#   66.800 production None
#   66.800 hand.chunk disc:2
#   66.800 B.chunk bot:None mid:None top:None
#   66.800 production move_to_C
#   66.850 production None
#   66.850 C.chunk bot:1 mid:2 top:None
#   66.850 hand.chunk disc:None
#   66.850 production pick_from_A
#   66.900 production None
#   66.900 hand.chunk disc:3
#   66.900 A.chunk bot:None mid:None top:None
#   66.900 production move_to_B
#   66.950 production None
#   66.950 B.chunk bot:3 mid:None top:None
#   66.950 hand.chunk disc:None
#   66.950 production move_to_B
#   67.000 production None
#   67.000 production pick_from_C
#   67.050 production None
#   67.050 hand.chunk disc:2
#   67.050 C.chunk bot:1 mid:None top:None
#   67.050 production move_to_B
#   67.100 production None
#   67.100 production move_to_C
#   67.150 production None
#   67.150 C.chunk bot:1 mid:2 top:None
#   67.150 hand.chunk disc:None
#   67.150 production pick_from_C
#   67.200 production None
#   67.200 hand.chunk disc:2
#   67.200 C.chunk bot:1 mid:None top:None
#   67.200 production move_to_B
#   67.250 production None
#   67.250 production move_to_B
#   67.300 production None
#   67.300 production move_to_A
#   67.350 production None
#   67.350 A.chunk bot:2 mid:None top:None
#   67.350 hand.chunk disc:None
#   67.350 production move_to_C
#   67.400 production None
#   67.400 production move_to_B
#   67.450 production None
#   67.450 production move_to_A
#   67.500 production None
#   67.500 production pick_from_C
#   67.550 production None
#   67.550 hand.chunk disc:1
#   67.550 C.chunk bot:None mid:None top:None
#   67.550 production move_to_A
#   67.600 production None
#   67.600 production move_to_A
#   67.650 production None
#   67.650 production move_to_B
#   67.700 production None
#   67.700 production move_to_A
#   67.750 production None
#   67.750 production move_to_A
#   67.800 production None
#   67.800 production move_to_C
#   67.850 production None
#   67.850 C.chunk bot:1 mid:None top:None
#   67.850 hand.chunk disc:None
#   67.850 production pick_from_B
#   67.900 production None
#   67.900 hand.chunk disc:3
#   67.900 B.chunk bot:None mid:None top:None
#   67.900 production move_to_B
#   67.950 production None
#   67.950 B.chunk bot:3 mid:None top:None
#   67.950 hand.chunk disc:None
#   67.950 production pick_from_B
#   68.000 production None
#   68.000 hand.chunk disc:3
#   68.000 B.chunk bot:None mid:None top:None
#   68.000 production move_to_C
#   68.050 production None
#   68.050 C.chunk bot:1 mid:3 top:None
#   68.050 hand.chunk disc:None
#   68.050 production move_to_C
#   68.100 production None
#   68.100 production move_to_A
#   68.150 production None
#   68.150 production pick_from_C
#   68.200 production None
#   68.200 hand.chunk disc:3
#   68.200 C.chunk bot:1 mid:None top:None
#   68.200 production move_to_C
#   68.250 production None
#   68.250 C.chunk bot:1 mid:3 top:None
#   68.250 hand.chunk disc:None
#   68.250 production move_to_B
#   68.300 production None
#   68.300 production move_to_B
#   68.350 production None
#   68.350 production move_to_A
#   68.400 production None
#   68.400 production pick_from_C
#   68.450 production None
#   68.450 hand.chunk disc:3
#   68.450 C.chunk bot:1 mid:None top:None
#   68.450 production move_to_B
#   68.500 production None
#   68.500 B.chunk bot:3 mid:None top:None
#   68.500 hand.chunk disc:None
#   68.500 production move_to_C
#   68.550 production None
#   68.550 production pick_from_A
#   68.600 production None
#   68.600 hand.chunk disc:2
#   68.600 A.chunk bot:None mid:None top:None
#   68.600 production move_to_C
#   68.650 production None
#   68.650 C.chunk bot:1 mid:2 top:None
#   68.650 hand.chunk disc:None
#   68.650 production move_to_C
#   68.700 production None
#   68.700 production pick_from_A
#   68.750 production None
#   68.750 production move_to_A
#   68.800 production None
#   68.800 production move_to_C
#   68.850 production None
#   68.850 production pick_from_A
#   68.900 production None
#   68.900 production move_to_A
#   68.950 production None
#   68.950 production move_to_C
#   69.000 production None
#   69.000 production pick_from_B
#   69.050 production None
#   69.050 hand.chunk disc:3
#   69.050 B.chunk bot:None mid:None top:None
#   69.050 production move_to_C
#   69.100 production None
#   69.100 C.chunk bot:1 mid:2 top:3
#   69.100 hand.chunk disc:None
#   69.100 production move_to_A
#   69.150 production None
#   69.150 production move_to_C
#   69.200 production None
#   69.200 production move_to_B
#   69.250 production None
#   69.250 production hanoi_finished
#   69.300 production None
#   69.300 A.chunk None
#   69.300 B.chunk None
#   69.300 C.chunk None
#   69.300 hand.chunk None
# finished
# this took 0 steps to complete

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()
