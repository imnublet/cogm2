# %%
import ccm
from ccm.lib.actr import *
import random as rand

# %%
import ccm
from ccm.lib.actr import *

class Hanoi_env(ACTR):
    A = Buffer()
    B = Buffer()
    C = Buffer()
    hand = Buffer()
    goal = Buffer()
    #goal = Buffer()
    
    
    def init():
        A.set('top:3 mid:2 bot:1')
        B.set('top:None mid:None bot:None')
        C.set('top:None mid:None bot:None')
        hand.set('disc:None')
#         goal.set(('top:3 mid:2 bot:1'))

#     def ren(finish='False'):
#         while(hanoi_finished() == True):
#         pick(hand)
#         place(hand)
    
    def hanoi_finished(C='top:3 mid:2 bot:1'):
        goal.clear()
        print 'finished'
    
#     def pick(hand = 'disc:?d'):
#         while(d == 'None'):
#                 pick_from_A(A)
#                 pick_from_B(B)
#                 pick_from_C(C)

                
#     def move(hand = 'disc:?d'):
#         while(d != 'None'):
#                 move_to_A(hand,A)
#                 move_to_B(hand,B)
#                 move_to_C(hand,C)
    
        
    def pick_from_A(A='top:?x mid:?y bot:?z', hand='None'):
        print 'De waarde in x is: '
        print x
        if str(x) != 'None':
            hand.modify('disc:x')
        elif str(y) != 'None':
            hand.modify('disc:y')
        elif str(z) != 'None':
            hand.modify('disc:z')
        
        
    def pick_from_B(B='top:?x mid:?y bot:?z'):
        if str(x) != 'None':
            hand.modify('disc:x')
        elif str(y) != 'None':
            hand.modify('disc:y')
        elif str(z) != 'None':
            hand.modify('disc:z')
        
    def pick_from_C(C='top:?x mid:?y bot:?z'):
        print 'haahahhah'
        if str(x) != 'None':
            hand.modify('disc:x')
        elif str(y) != 'None':
            hand.modify('disc:y')
        elif str(z) != 'None':
            hand.modify('disc:z')

    
    
    def move_to_A(hand='disc:?d', A='top:?x mid:?y bot:?z'):
        if str(d) != 'None':
            if str(z) == 'None':
                hand.modify('disc:None')
                A.modify('bot:d')
            elif str(y) == 'None' and str(z)!= 'None' and int(d) > int(z):
                hand.modify('disc:None')
                A.modify('mid:d')
            elif str(x) == 'None' and str(y)!= 'None' and int(d) > int(y):
                hand.modify('disc:None')
                A.modify('top:d')
    
    
    def move_to_B(hand='disc:?d', B='top:?x mid:?y bot:?z'):
        if str(d) != 'None':
            if str(z) == 'None':
                hand.modify('disc:None')
                B.modify('bot:d')
            elif y == 'None' and z!= 'None' and int(d) > int(z):
                hand.modify('disc:None')
                B.modify('mid:d')
            elif str(x) == 'None' and y!= 'None' and int(d) > int(y):
                hand.modify('disc:None')
                B.modify('top:d')
        
    def move_to_C(hand='disc:?d', C='top:?x mid:?y bot:?z'):
        if str(d) != 'None':
            if str(z) == 'None':
                hand.modify('disc:None')
                C.modify('bot:d')
            elif str(y) == 'None' and str(z) != 'None' and int(d) > int(z):
                hand.modify('disc:None')
                C.modify(mid = 'd')
            elif str(x) == 'None' and str(y) != 'None' and int(d) > int(y):
                hand.modify('disc:None')
                C.modify('top:d')

# %%
#Run model
model=Hanoi_env()

# model.A.set('top:3 mid:2 bot:1')
# model.B.set('top:None mid:None bot:None')
# model.C.set('top:None mid:None bot:None')
# model.hand.set('disc:None')
ccm.log_everything(model)
model.A.set('top:3 mid:2 bot:1')
# model.run()
model.A.__getitem__('top')
# Out:
# 316936.550 production_threshold None
# 316936.550 production_time_sd None
# 316936.550 production_match_delay 0
# 316936.550 production_time 0.05
# 316936.550 goal.chunk None
# 316936.550 A.chunk bot:1 mid:2 top:3
# '3'
